# %% [markdown]
# ### Bitcoin Price Prediction(Data Science)

# %% [markdown]
# ##### Microtask-1

# %% [markdown]
# pip3 install pandas

# %% [markdown]
# ##### Microtask-2

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df=pd.read_csv(r'https://raw.githubusercontent.com/WidhyaOrg/datasets/master/bitcoin_dataset.csv')
df.head()
# Out:
#         Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0  2/17/2010               0.0           2043200.0             0.0
# 1  2/18/2010               0.0           2054650.0             0.0
# 2  2/19/2010               0.0           2063600.0             0.0
# 3  2/20/2010               0.0           2074700.0             0.0
# 4  2/21/2010               0.0           2085400.0             0.0
#
#    btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 0               0.0              0.0            0.000235
# 1               0.0              0.0            0.000241
# 2               0.0              0.0            0.000228
# 3               0.0              0.0            0.000218
# 4               0.0              0.0            0.000234
#
#    btc_n_orphaned_blocks  btc_n_transactions_per_block  \
# 0                      0                           1.0
# 1                      0                           1.0
# ...

# %%
df["btc_market_price"].iloc[1023]
# Out:
# 13.688800000000001

# %% [markdown]
# ##### Microtask-3

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.jointplot(data=df,x="btc_market_price",y="btc_market_cap")
plt.show()

# %% [markdown]
# #### "btc_market_cap" shows a perfact correlaton with "btc_market_price"

# %% [markdown]
# ##### Microtask-4

# %%
df.isnull().sum()
# Out:
# Date                                                    0
# btc_market_price                                        0
# btc_total_bitcoins                                     27
# btc_market_cap                                          0
# btc_trade_volume                                       21
# btc_blocks_size                                        29
# btc_avg_block_size                                      0
# btc_n_orphaned_blocks                                   0
# btc_n_transactions_per_block                            0
# btc_median_confirmation_time                           12
# btc_hash_rate                                           0
# btc_difficulty                                         16
# btc_miners_revenue                                      0
# btc_transaction_fees                                   10
# btc_cost_per_transaction_percent                        0
# btc_cost_per_transaction                                0
# ...

# %%
df1=df.copy()
df1.head()
# Out:
#         Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0  2/17/2010               0.0           2043200.0             0.0
# 1  2/18/2010               0.0           2054650.0             0.0
# 2  2/19/2010               0.0           2063600.0             0.0
# 3  2/20/2010               0.0           2074700.0             0.0
# 4  2/21/2010               0.0           2085400.0             0.0
#
#    btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 0               0.0              0.0            0.000235
# 1               0.0              0.0            0.000241
# 2               0.0              0.0            0.000228
# 3               0.0              0.0            0.000218
# 4               0.0              0.0            0.000234
#
#    btc_n_orphaned_blocks  btc_n_transactions_per_block  \
# 0                      0                           1.0
# 1                      0                           1.0
# ...

# %%
df2=df1.fillna(method='bfill')
df2
# Out:
#            Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0     2/17/2010           0.00000           2043200.0    0.000000e+00
# 1     2/18/2010           0.00000           2054650.0    0.000000e+00
# 2     2/19/2010           0.00000           2063600.0    0.000000e+00
# 3     2/20/2010           0.00000           2074700.0    0.000000e+00
# 4     2/21/2010           0.00000           2085400.0    0.000000e+00
# 5     2/22/2010           0.00000           2098150.0    0.000000e+00
# 6     2/23/2010           0.00000           2110700.0    0.000000e+00
# 7     2/24/2010           0.00000           2120200.0    0.000000e+00
# 8     2/25/2010           0.00000           2127600.0    0.000000e+00
# 9     2/26/2010           0.00000           2136100.0    0.000000e+00
# 10    2/27/2010           0.00000           2144750.0    0.000000e+00
# 11    2/28/2010           0.00000           2152850.0    0.000000e+00
# ...

# %%
df2.isnull().sum()
# Out:
# Date                                                   0
# btc_market_price                                       0
# btc_total_bitcoins                                     0
# btc_market_cap                                         0
# btc_trade_volume                                       0
# btc_blocks_size                                        0
# btc_avg_block_size                                     0
# btc_n_orphaned_blocks                                  0
# btc_n_transactions_per_block                           0
# btc_median_confirmation_time                           0
# btc_hash_rate                                          0
# btc_difficulty                                         0
# btc_miners_revenue                                     0
# btc_transaction_fees                                   0
# btc_cost_per_transaction_percent                       0
# btc_cost_per_transaction                               0
# ...

# %% [markdown]
# ##### "fillna" is the function in pandas allows you to fill cells in a coumn that have NaN values.

# %% [markdown]
# ##### Microtask-5

# %%
X=df2[["btc_market_cap","btc_n_transactions","btc_miners_revenue","btc_cost_per_transaction","btc_difficulty","btc_hash_rate","btc_cost_per_transaction_percent"]]
X
# Out:
#       btc_market_cap  btc_n_transactions  btc_miners_revenue  \
# 0       0.000000e+00                 244                0.00
# 1       0.000000e+00                 235                0.00
# 2       0.000000e+00                 183                0.00
# 3       0.000000e+00                 224                0.00
# 4       0.000000e+00                 218                0.00
# 5       0.000000e+00                 261                0.00
# 6       0.000000e+00                 252                0.00
# 7       0.000000e+00                 196                0.00
# 8       0.000000e+00                 150                0.00
# 9       0.000000e+00                 176                0.00
# 10      0.000000e+00                 176                0.00
# 11      0.000000e+00                 165                0.00
# 12      0.000000e+00                 187                0.00
# 13      0.000000e+00                 204                0.00
# ...

# %%
y=df2["btc_market_price"]
y
# Out:
# 0           0.00000
# 1           0.00000
# 2           0.00000
# 3           0.00000
# 4           0.00000
# 5           0.00000
# 6           0.00000
# 7           0.00000
# 8           0.00000
# 9           0.00000
# 10          0.00000
# 11          0.00000
# 12          0.00000
# 13          0.00000
# 14          0.00000
# 15          0.00000
# 16          0.00000
# 17          0.00000
# 18          0.00000
# 19          0.00000
# 20          0.00000
# 21          0.00000
# 22          0.00000
# 23          0.00000
# 24          0.00000
# 25          0.00000
# 26          0.00000
# 27          0.00000
# 28          0.00000
# 29          0.00000
#            ...
# 2876    15005.85667
# 2877    15053.26167
# 2878    15199.35500
# 2879    17174.12000
# 2880    17319.19800
# 2881    16651.47167
# 2882    15265.90667
# 2883    14714.25333
# 2884    15126.39833
# 2885    13296.79400
# 2886    13912.88200
# 2887    14499.77333
# 2888    13852.92000
# 2889    14012.19600
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

from sklearn.linear_model import LinearRegression
model=LinearRegression()

train=model.fit(X_train,y_train)

# %%
train.coef_
# Out:
# array([  5.95803676e-08,   2.98788856e-04,  -7.78594217e-06,
#          3.69569395e+00,  -5.82500992e-11,  -5.64589706e-06,
#          8.70175735e-04])

# %%
train.intercept_
# Out:
# -13.330296701582711

# %%
train.score(X_train,y_train)
# Out:
# 0.99992949788240137

# %%
pred=train.predict(X_test)
pred
# Out:
# array([  7.49642650e+01,   1.14568491e+01,   6.21332115e+02,
#          5.77350487e+01,   1.69395961e+01,   6.48561569e+02,
#         -1.31354842e+01,  -1.43828632e+00,   1.29260115e+01,
#          4.78150793e+02,   2.32062699e+02,   2.97804539e+00,
#          1.29415708e+02,  -1.31555233e+01,   5.01148466e+02,
#          6.65332913e+01,   2.23847242e+02,   1.28442840e+03,
#          2.72107100e+01,   3.29809007e+02,   8.29942483e+00,
#          1.16938640e+01,  -4.21374573e+00,   2.66816269e+02,
#          2.35771741e+02,   5.89671107e+02,   3.18939237e+02,
#          2.37509550e+01,   2.71516047e+00,   9.29456229e+02,
#         -1.31821903e+01,   6.17486692e+02,   4.29523939e+02,
#          3.73869236e+01,   2.29856239e+00,   1.27044274e+02,
#          1.14913558e+00,   3.78312616e+02,   6.16894895e+01,
#          6.17824248e+01,   5.97969759e+02,   4.71219978e+02,
#          5.67924176e+03,   5.92178306e+02,   6.59052772e+02,
# ...

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
MSE=mean_squared_error(y_test,pred)
MSE
# Out:
# 423.04116492536281

# %%
MAE=mean_absolute_error(y_test,pred)
MAE
# Out:
# 13.035748541531367

# %%
plt.figure(figsize=(30,20))
sns.heatmap(df.corr(),annot=True)
